# %% [markdown]
# # Python Data Analysis Tasks

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# ### Task 1 - Data Ingestion

# %%
raw_df = pd.read_excel("Data.xlsx", header = 1, parse_dates = ['Response Date'])
raw_df
# Load excel file and set the header index to 1 (header is in row with index position 1 in excel file). 
# 1000 x 19 which is what we wanted.
# Out:
#      Response id Response Date Department Manager Gender-1 Gender-2  \
# 0              4    2020-07-13         IT      No      NaN   Female
# 1             21    2020-07-13  Marketing      No      NaN     Male
# 2             22    2020-07-13    Finance      No      NaN   Female
# 3             25    2020-07-13    Finance      No      NaN     Male
# 4             54    2020-07-13      Legal      No      NaN     Male
# ..           ...           ...        ...     ...      ...      ...
# 995          899    2020-07-24      Legal     Yes   Female      NaN
# 996          901    2020-07-24  Marketing     Yes  Female       NaN
# 997          908    2020-07-24    Finance     Yes   Female      NaN
# 998          910    2020-07-24         IT     Yes     Male      NaN
# 999          969    2020-07-24      Legal     Yes  Female       NaN
#
#     Company Grade  \
# 0               A
# 1               C
# 2               A
# 3               B
# 4               B
# ..            ...
# 995             D
# 996             D
# 997             D
# 998             D
# 999             D
#
#      Universal Exports does a good job of keeping me informed about important news and events  \
# 0                                                    5
# 1                                                    4
# 2                                                    5
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 995                                                  4
# 996                                                  1
# 997                                                  3
# 998                                                  4
# 999                                                  4
#
#      I get a sense of achievement from the work I do in my job   \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 995                                                  4
# 996                                                  1
# 997                                                  5
# 998                                                  4
# 999                                                  4
#
#      Universal Exports has created an environment that encourages me to perform to the best of my abilities  \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 995                                                  3
# 996                                                  1
# 997                                                  4
# 998                                                  4
# 999                                                  3
#
#      I am proud to work for Universal Exports  \
# 0                                           5
# 1                                           4
# 2                                           4
# 3                                           4
# 4                                           4
# ..                                        ...
# 995                                         4
# 996                                         1
# 997                                         5
# 998                                         5
# 999                                         3
#
#      I trust and respect the management of Universal Exports  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 995                                                  4
# 996                                                  1
# 997                                                  3
# 998                                                  4
# 999                                                  3
#
#      I believe that Universal Exports really cares about my health and wellbeing   \
# 0                                                    3
# 1                                                    5
# 2                                                    3
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 995                                                  4
# 996                                                  1
# 997                                                  4
# 998                                                  4
# 999                                                  4
#
#      All in all, Universal Exports is effectively managed and well-run  \
# 0                                                    4
# 1                                                    3
# 2                                                    3
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 995                                                  4
# 996                                                  1
# 997                                                  4
# 998                                                  4
# 999                                                  2
#
#      I believe that Universal Exports has fair and transparent processes for promoting people into new roles  \
# 0                                                    4
# 1                                                    3
# 2                                                    2
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 995                                                  3
# 996                                                  1
# 997                                                  3
# 998                                                  4
# 999                                                  2
#
#      I have access to opportunities to develop my career in Universal Exports  \
# 0                                                    2
# 1                                                    4
# 2                                                    4
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 995                                                  3
# 996                                                  1
# 997                                                  1
# 998                                                  4
# 999                                                  3
#
#      My manager treats me fairly  NPDSK  deqt43t
# 0                              4    NaN      NaN
# 1                              5    NaN      NaN
# 2                              4    NaN      NaN
# 3                              5    NaN      NaN
# 4                              4    NaN      NaN
# ..                           ...    ...      ...
# 995                            4    NaN      NaN
# 996                            1    NaN      NaN
# 997                            4    NaN      NaN
# 998                            3    NaN      NaN
# 999                            3    NaN      NaN
#
# [1000 rows x 19 columns]

# %%
df = raw_df.copy()

# %%
# General overview info about our dataset

# df.isna().sum()
# df.describe()
df.dtypes
# Out:
# Response id                                                                                                         int64
# Response Date                                                                                              datetime64[ns]
# Department                                                                                                         object
# Manager                                                                                                            object
# Gender-1                                                                                                           object
# Gender-2                                                                                                           object
# Company Grade                                                                                                      object
# Universal Exports does a good job of keeping me informed about important news and events                            int64
# I get a sense of achievement from the work I do in my job                                                           int64
# Universal Exports has created an environment that encourages me to perform to the best of my abilities              int64
# I am proud to work for Universal Exports                                                                            int64
# I trust and respect the management of Universal Exports                                                             int64
# I believe that Universal Exports really cares about my health and wellbeing                                         int64
# All in all, Universal Exports is effectively managed and well-run                                                   int64
# I believe that Universal Exports has fair and transparent processes for promoting people into new roles             int64
# I have access to opportunities to develop my career in Universal Exports                                            int64
# My manager treats me fairly                                                                                         int64
# NPDSK                                                                                                             float64
# deqt43t                                                                                                           float64
# dtype: object

# %% [markdown]
# ### Task 2 - Data Transformation

# %% [markdown]
# **Rename the "Company Grade" column as "Grade"**

# %%
df.rename({"Company Grade": "Grade"}, axis = "columns", inplace = True)
df.head()
# Out:
#    Response id Response Date Department Manager Gender-1 Gender-2 Grade  \
# 0            4    2020-07-13         IT      No      NaN   Female     A
# 1           21    2020-07-13  Marketing      No      NaN     Male     C
# 2           22    2020-07-13    Finance      No      NaN   Female     A
# 3           25    2020-07-13    Finance      No      NaN     Male     B
# 4           54    2020-07-13      Legal      No      NaN     Male     B
#
#    Universal Exports does a good job of keeping me informed about important news and events  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  3
# 4                                                  4
#
#    I get a sense of achievement from the work I do in my job   \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    Universal Exports has created an environment that encourages me to perform to the best of my abilities  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I am proud to work for Universal Exports  \
# 0                                         5
# 1                                         4
# 2                                         4
# 3                                         4
# 4                                         4
#
#    I trust and respect the management of Universal Exports  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    I believe that Universal Exports really cares about my health and wellbeing   \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    All in all, Universal Exports is effectively managed and well-run  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I believe that Universal Exports has fair and transparent processes for promoting people into new roles  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    I have access to opportunities to develop my career in Universal Exports  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    My manager treats me fairly  NPDSK  deqt43t
# 0                            4    NaN      NaN
# 1                            5    NaN      NaN
# 2                            4    NaN      NaN
# 3                            5    NaN      NaN
# 4                            4    NaN      NaN

# %% [markdown]
# **Merge columns "Gender 1" and "Gender 2"**

# %%
# Fill null values in "Gender-1" with values in "Gender-2" for the corresponding row.
df = df.assign(**{'Gender-1': df['Gender-1'].fillna(df['Gender-2'])})

# %%
# Drop columns "Gender-2"
df.drop(columns = ['Gender-2'], inplace = True)

# %%
# Rename column "Gender-1"  to "Gender". 
df.rename({"Gender-1": "Gender"}, axis = 1, inplace = True)
gender_nulls = df['Gender'].isnull().sum()

print(f"There are {gender_nulls} null values in the Gender column. Gender-1 and Gender-2 merged succesfully.")
# Out:
# There are 0 null values in the Gender column. Gender-1 and Gender-2 merged succesfully.

# %%
# Check all values in "Gender" column are in consistent format
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Female '], dtype=object)

# %%
# Remove space before and after the value
df['Gender'] = df['Gender'].str.strip()
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# **Remove columns 'NPDSK' and 'deqt43t'**

# %%
df.drop(columns = ['NPDSK', 'deqt43t'], inplace = True)
df.columns
# Out:
# Index(['Response id', 'Response Date', 'Department', 'Manager', 'Gender',
#        'Grade',
#        'Universal Exports does a good job of keeping me informed about important news and events',
#        'I get a sense of achievement from the work I do in my job ',
#        'Universal Exports has created an environment that encourages me to perform to the best of my abilities',
#        'I am proud to work for Universal Exports',
#        'I trust and respect the management of Universal Exports',
#        'I believe that Universal Exports really cares about my health and wellbeing ',
#        'All in all, Universal Exports is effectively managed and well-run',
#        'I believe that Universal Exports has fair and transparent processes for promoting people into new roles',
#        'I have access to opportunities to develop my career in Universal Exports',
#        'My manager treats me fairly'],
#       dtype='object')

# %% [markdown]
# **Add a conditional column**
#
# Conditional column shows whether respondents' responses to *Universal Exports does a good job of keeping me informed about important news and events* was positive, neutral or negative.

# %%
swap_rating = {1: 'Negative', 
              2: 'Negative', 
              3: 'Neutral', 
              4: 'Positive', 
              5: 'Positive'}
    
df['Conditional Column'] = df['Universal Exports does a good job of keeping me informed about important news and events']
df['Conditional Column'] = df['Conditional Column'].map(swap_rating)

df.head()
# Out:
#    Response id Response Date Department Manager  Gender Grade  \
# 0            4    2020-07-13         IT      No  Female     A
# 1           21    2020-07-13  Marketing      No    Male     C
# 2           22    2020-07-13    Finance      No  Female     A
# 3           25    2020-07-13    Finance      No    Male     B
# 4           54    2020-07-13      Legal      No    Male     B
#
#    Universal Exports does a good job of keeping me informed about important news and events  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  3
# 4                                                  4
#
#    I get a sense of achievement from the work I do in my job   \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    Universal Exports has created an environment that encourages me to perform to the best of my abilities  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I am proud to work for Universal Exports  \
# 0                                         5
# 1                                         4
# 2                                         4
# 3                                         4
# 4                                         4
#
#    I trust and respect the management of Universal Exports  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    I believe that Universal Exports really cares about my health and wellbeing   \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    All in all, Universal Exports is effectively managed and well-run  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I believe that Universal Exports has fair and transparent processes for promoting people into new roles  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    I have access to opportunities to develop my career in Universal Exports  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    My manager treats me fairly Conditional Column
# 0                            4           Positive
# 1                            5           Positive
# 2                            4           Positive
# 3                            5            Neutral
# 4                            4           Positive

# %% [markdown]
# **Add a custom column**
#
# The custom column shows both 'Gender' and whether respondents answered positively, neutrally or negatively to *Universal Exports does a good job of keeping me informed about important news and events*

# %%
df['Custom Column'] = df['Gender'] + "-" + df['Conditional Column']
df.head()
# Out:
#    Response id Response Date Department Manager  Gender Grade  \
# 0            4    2020-07-13         IT      No  Female     A
# 1           21    2020-07-13  Marketing      No    Male     C
# 2           22    2020-07-13    Finance      No  Female     A
# 3           25    2020-07-13    Finance      No    Male     B
# 4           54    2020-07-13      Legal      No    Male     B
#
#    Universal Exports does a good job of keeping me informed about important news and events  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  3
# 4                                                  4
#
#    I get a sense of achievement from the work I do in my job   \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    Universal Exports has created an environment that encourages me to perform to the best of my abilities  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I am proud to work for Universal Exports  \
# 0                                         5
# 1                                         4
# 2                                         4
# 3                                         4
# 4                                         4
#
#    I trust and respect the management of Universal Exports  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    I believe that Universal Exports really cares about my health and wellbeing   \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    All in all, Universal Exports is effectively managed and well-run  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I believe that Universal Exports has fair and transparent processes for promoting people into new roles  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    I have access to opportunities to develop my career in Universal Exports  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    My manager treats me fairly Conditional Column    Custom Column
# 0                            4           Positive  Female-Positive
# 1                            5           Positive    Male-Positive
# 2                            4           Positive  Female-Positive
# 3                            5            Neutral     Male-Neutral
# 4                            4           Positive    Male-Positive

# %% [markdown]
# **Unpivot all the question columns**

# %%
id_variables = list(df.columns[:6])
value_variables = list(df.columns[6:])

id_variables
df_melted =  pd.melt(df, id_vars = id_variables, value_vars = value_variables, var_name = "Question", value_name = "Answer")

# %%
df_melted
# Out:
#        Response id Response Date Department Manager  Gender Grade  \
# 0                4    2020-07-13         IT      No  Female     A
# 1               21    2020-07-13  Marketing      No    Male     C
# 2               22    2020-07-13    Finance      No  Female     A
# 3               25    2020-07-13    Finance      No    Male     B
# 4               54    2020-07-13      Legal      No    Male     B
# ...            ...           ...        ...     ...     ...   ...
# 11995          899    2020-07-24      Legal     Yes  Female     D
# 11996          901    2020-07-24  Marketing     Yes  Female     D
# 11997          908    2020-07-24    Finance     Yes  Female     D
# 11998          910    2020-07-24         IT     Yes    Male     D
# 11999          969    2020-07-24      Legal     Yes  Female     D
#
#                                                 Question           Answer
# 0      Universal Exports does a good job of keeping m...                5
# 1      Universal Exports does a good job of keeping m...                4
# 2      Universal Exports does a good job of keeping m...                5
# 3      Universal Exports does a good job of keeping m...                3
# 4      Universal Exports does a good job of keeping m...                4
# ...                                                  ...              ...
# 11995                                      Custom Column  Female-Positive
# 11996                                      Custom Column  Female-Negative
# 11997                                      Custom Column   Female-Neutral
# 11998                                      Custom Column    Male-Positive
# 11999                                      Custom Column  Female-Positive
#
# [12000 rows x 8 columns]

# %% [markdown]
# ### Task 3 - Exporting Final Output and Analysis

# %%
output = df_melted.copy()

# %%
output.to_excel("Data_Modified.xlsx", index = False)
